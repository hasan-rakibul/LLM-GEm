# %%
import numpy as np
import pandas as pd
import os

import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset

from transformers import (
    DataCollatorWithPadding,
    AutoModel,
    AutoTokenizer
)
from datasets import Dataset

os.chdir("/g/data/jr19/rh2942/text-empathy/")
from evaluation import pearsonr
from utils.utils import plot, get_device, set_all_seeds

# %%
os.environ['TOKENIZERS_PARALLELISM'] = 'false' # due to huggingface warning
os.environ['TRANSFORMERS_NO_ADVISORY_WARNINGS'] = 'true'

# %%
class DataModule():
    def __init__(self, task_list, checkpoint, batch_size, feature_to_tokenise):
        super(DataModule, self).__init__()
        self.task_list = task_list
        self.checkpoint = checkpoint
        self.batch_size = batch_size
        self.tokeniser = AutoTokenizer.from_pretrained(
            self.checkpoint,
            use_fast=True
        )
        self.data_collator = DataCollatorWithPadding(tokenizer=self.tokeniser)
        self.feature_to_tokenise = feature_to_tokenise # to tokenise function
    
    def _process_raw(self, path, send_label):
        data = pd.read_csv(path, sep='\t')
    
        if send_label:
            data = data[self.feature_to_tokenise + self.task_list]
        else:
            data = data[self.feature_to_tokenise]
            
        return data

    def _tokeniser_fn(self, sentence):
        if len(self.feature_to_tokenise) == 1: # only one feature
            return self.tokeniser(sentence[self.feature_to_tokenise[0]], truncation=True)
        # otherwise tokenise a pair of sentence
        return self.tokeniser(sentence[self.feature_to_tokenise[0]], sentence[self.feature_to_tokenise[1]], truncation=True)

    def _process_input(self, file, send_label):
        data = self._process_raw(path=file, send_label=send_label)
        data = data.reset_index(drop=True)
        data = Dataset.from_pandas(data, preserve_index=False) # convert to huggingface dataset
        data = data.map(self._tokeniser_fn, batched=True, remove_columns=self.feature_to_tokenise) # tokenise
        data = data.with_format('torch')
        return data

    def dataloader(self, file, send_label, shuffle):
        data = self._process_input(file=file, send_label=send_label)
        return DataLoader(
            data,
            batch_size=self.batch_size,
            shuffle=shuffle,
            collate_fn=self.data_collator,
            num_workers=24
        )

# %%
class Guide(nn.Module):
    def __init__(self, checkpoint):
        super(Guide, self).__init__()
        self.transformer = AutoModel.from_pretrained(checkpoint)
        self.dropout = nn.Dropout(0.2)
        
        self.pre_classifier = nn.Linear(768, 768)
        
        self.classifier = nn.Linear(768, 512)
        self.pre_final = nn.Linear(512, 256)
        self.final = nn.Linear(256, 1)

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        # token_type_ids=None,
    ):

        output = self.transformer(
            input_ids=input_ids,
            attention_mask=attention_mask,
            # token_type_ids=token_type_ids
        )
        
        output = output[0]
        output = output[:, 0]

        output = self.pre_classifier(output)
        
        output = nn.ReLU()(output)
        output = self.dropout(output)
        output = self.classifier(output)
        output = nn.ReLU()(output)
        output = self.pre_final(output)
        output = nn.ReLU()(output)
        output = self.final(output)
        return output

# %%
class Predictor(nn.Module):
    def __init__(self, checkpoint):
        super(Predictor, self).__init__()
        self.transformer = AutoModel.from_pretrained(checkpoint)
        self.dropout = nn.Dropout(0.2)
        
        self.pre_classifier = nn.Linear(769, 768)
        
        self.classifier = nn.Linear(768, 512)
        self.pre_final = nn.Linear(512, 256)
        self.final = nn.Linear(256, 1)

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        # token_type_ids=None,
        guide=None
    ):

        output = self.transformer(
            input_ids=input_ids,
            attention_mask=attention_mask,
            # token_type_ids=token_type_ids
        )
        
        output = output[0]
        output = output[:, 0]

        output = torch.cat([output, guide], 1)
        output = self.pre_classifier(output)
    
        output = nn.ReLU()(output)
        output = self.dropout(output)
        output = self.classifier(output)
        output = nn.ReLU()(output)
        output = self.pre_final(output)
        output = nn.ReLU()(output)
        output = self.final(output)
        return output

# %%
class Trainer:
    def __init__(self, task_guide, task_predictor, model_guide, model_predictor, lr):
        self.device = get_device(0)
        
        self.task_guide = task_guide
        self.task_predictor = task_predictor
        self.model_guide = model_guide.to(self.device)
        self.model_predictor = model_predictor.to(self.device)
        
        self.lr = lr
        self.loss_fn = nn.MSELoss()
        
        self.optimizer_guide = torch.optim.Adam(params=self.model_guide.parameters(), lr = self.lr)
        self.optimizer_predictor = torch.optim.Adam(params=self.model_predictor.parameters(), lr = self.lr)
        
        self.best_pearson_r = -1.0 # initiliasation

    def _training_step(self, epoch, train_loader):
        tr_loss = 0.0
        
        self.model_guide.train()
        self.model_predictor.train()
    
        for i, data in enumerate(train_loader, 0):
            input_ids = data['input_ids'].to(self.device, dtype=torch.long)
            attention_mask = data['attention_mask'].to(self.device, dtype=torch.long)
            # token_type_ids = data['token_type_ids'].to(self.device, dtype=torch.long)
            guide = data[self.task_guide].to(self.device, dtype=torch.float).view(-1, 1)
            targets = data[self.task_predictor].to(self.device, dtype=torch.float).view(-1, 1)
            
            outputs = self.model_guide(
                input_ids=input_ids,
                attention_mask=attention_mask,
                # token_type_ids=token_type_ids,
            )          
            loss = self.loss_fn(outputs, guide)
            self.optimizer_guide.zero_grad()
            loss.backward(retain_graph=True)
            self.optimizer_guide.step()

            final_outputs = self.model_predictor(
                input_ids=input_ids,
                attention_mask=attention_mask,
                # token_type_ids=token_type_ids,
                guide=outputs
            )
            
            final_loss = self.loss_fn(final_outputs, targets)
            self.optimizer_predictor.zero_grad()
            final_loss.backward()
            self.optimizer_predictor.step()
            
            tr_loss += final_loss.item()
    
            if i % 50 == 0:
                loss_step = tr_loss / (i+1)
                print(f'Training loss per 50 steps: {loss_step}')
    
        epoch_loss = tr_loss / (i+1)
        print(f'Epoch: {epoch+1}')
        print(f'The total loss: {epoch_loss}')

    def fit(self, n_epochs, train_loader, dev_loader, output_label, save_model=False):
        for epoch in range(n_epochs):
            self._training_step(epoch, train_loader)

            preds = self.evaluate(dataloader=dev_loader, load_model=False)
            if self.task_predictor == 'empathy':
                true = output_label.iloc[:, 0].tolist()
            if self.task_predictor == 'distress':
                true = output_label.iloc[:, 1].tolist()
            pearson_r = pearsonr(true, preds)
            print(f'Pearson r: {pearson_r}')
            
            if save_model and (pearson_r > self.best_pearson_r):
                self.best_pearson_r = pearson_r   
                torch.save(self.model_guide.state_dict(), 'roberta-guide-empathy.pth')
                torch.save(self.model_predictor.state_dict(), 'roberta-predictor-empathy.pth')
                print("Saved the model in epoch " + str(epoch+1))

    def evaluate(self, dataloader, load_model=False):
        if load_model:
            self.model_guide.load_state_dict(torch.load('roberta-guide-empathy.pth'))
            self.model_predictor.load_state_dict(torch.load('roberta-predictor-empathy.pth'))
    
        pred = torch.empty((len(dataloader.dataset), 1), device=self.device) # len(self.dev_loader.dataset) --> # of samples
        
        self.model_guide.eval()
        self.model_predictor.eval()
    
        with torch.no_grad():
            idx = 0
            for data in dataloader:
                input_ids = data['input_ids'].to(self.device, dtype=torch.long)
                attention_mask = data['attention_mask'].to(self.device, dtype=torch.long)
                # token_type_ids = data['token_type_ids'].to(self.device, dtype=torch.long)
                
                outputs = self.model_guide(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    # token_type_ids=token_type_ids,
                )
    
                final_outputs = self.model_predictor(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    # token_type_ids=token_type_ids,
                    guide=outputs
                )

                batch_size = final_outputs.shape[0]
                pred[idx:idx+batch_size, :] = final_outputs
                idx += batch_size
            
        return [float(k) for k in pred]

# %%
BATCH_SIZE = 8
lr = 1e-05
checkpoint = 'roberta-base'
task_list = ['empathy', 'distress']

train_file = './data/PREPROCESSED-WS22-WS23-train.tsv'

# WASSA 2022
# dev_file = './data/PREPROCESSED-WS22-dev.tsv'
# dev_label_file = './data/WASSA22/goldstandard_dev_2022.tsv'
# test_file = './data/PREPROCESSED-WS22-test.tsv'

# WASSA 2023
dev_file = './data/PREPROCESSED-WS23-dev.tsv'
dev_label_file = './data/WASSA23/goldstandard_dev.tsv'
test_file = './data/PREPROCESSED-WS23-test.tsv'

# %%
data_module = DataModule(
    task_list=task_list,
    checkpoint=checkpoint,
    batch_size=BATCH_SIZE,
    feature_to_tokenise=['demographic_essay', 'article']
)

# %%
train_loader = data_module.dataloader(file=train_file, send_label=True, shuffle=True)
dev_loader = data_module.dataloader(file=dev_file, send_label=False, shuffle=False)
# Out:
# Map:   0%|          | 0/2636 [00:00<?, ? examples/s]
# Map:   0%|          | 0/208 [00:00<?, ? examples/s]

# %%
dev_label = pd.read_csv(dev_label_file, sep='\t', header=None)

# %%
set_all_seeds(0)
model_guide = Guide(checkpoint=checkpoint)
model_predictor = Predictor(checkpoint=checkpoint)

trainer = Trainer(
    task_guide=task_list[1],
    task_predictor=task_list[0],
    model_guide=model_guide,
    model_predictor=model_predictor,
    lr=lr
)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.fit(n_epochs=20, train_loader=train_loader, dev_loader=dev_loader,
            output_label=dev_label, save_model=True)
# Out:
# Training loss per 50 steps: 18.687795639038086
# Training loss per 50 steps: 16.35341345095167
# Training loss per 50 steps: 12.853866619638877
# Training loss per 50 steps: 10.030268036766557
# Training loss per 50 steps: 8.461887044100026
# Training loss per 50 steps: 7.525218012798355
# Training loss per 50 steps: 6.91431711282445
# Epoch: 1
# The total loss: 6.610729033296758
# Pearson r: 0.162
# Saved the model in epoch 1
# Training loss per 50 steps: 3.240436315536499
# Training loss per 50 steps: 3.881721057143866
# Training loss per 50 steps: 3.591704461244073
# Training loss per 50 steps: 3.4685914923023704
# Training loss per 50 steps: 3.462682224921326
# Training loss per 50 steps: 3.5199079480304185
# Training loss per 50 steps: 3.475900487646312
# Epoch: 2
# The total loss: 3.4165198667482897
# Pearson r: 0.354
# Saved the model in epoch 2
# Training loss per 50 steps: 2.496554374694824
# Training loss per 50 steps: 2.8197640741572663
# Training loss per 50 steps: 2.719561696642696
# Training loss per 50 steps: 2.854794906069901
# Training loss per 50 steps: 2.7734148413387696
# Training loss per 50 steps: 2.714550784384587
# Training loss per 50 steps: 2.6841612827540238
# Epoch: 3
# The total loss: 2.689232484048063
# Pearson r: 0.495
# Saved the model in epoch 3
# Training loss per 50 steps: 3.579223394393921
# Training loss per 50 steps: 2.2863543068661407
# Training loss per 50 steps: 2.1541697022938493
# Training loss per 50 steps: 2.1198940687621666
# Training loss per 50 steps: 2.191343497281051
# Training loss per 50 steps: 2.18819068342566
# Training loss per 50 steps: 2.169247928944933
# Epoch: 4
# The total loss: 2.168374090122454
# Pearson r: 0.528
# Saved the model in epoch 4
# Training loss per 50 steps: 2.037271022796631
# Training loss per 50 steps: 1.639618886452095
# Training loss per 50 steps: 1.7295381698277916
# Training loss per 50 steps: 1.6099529226884146
# Training loss per 50 steps: 1.6421448706987485
# Training loss per 50 steps: 1.5981822116560196
# Training loss per 50 steps: 1.6184999945254817
# Epoch: 5
# The total loss: 1.5907736656792235
# Pearson r: 0.51
# Training loss per 50 steps: 0.39218956232070923
# Training loss per 50 steps: 1.047133592413921
# Training loss per 50 steps: 0.9875170470464347
# Training loss per 50 steps: 1.0480379436584497
# Training loss per 50 steps: 1.0457370436903257
# Training loss per 50 steps: 1.0490166081850272
# Training loss per 50 steps: 1.0523689661509175
# Epoch: 6
# The total loss: 1.0497438923427553
# Pearson r: 0.503
# Training loss per 50 steps: 0.6429117321968079
# Training loss per 50 steps: 0.7584292123130724
# Training loss per 50 steps: 0.7753040395160713
# Training loss per 50 steps: 0.7603285290942287
# Training loss per 50 steps: 0.7267603618069668
# Training loss per 50 steps: 0.7661088914480579
# Training loss per 50 steps: 0.7742814701731221
# Epoch: 7
# The total loss: 0.7604057054515138
# Pearson r: 0.511
# Training loss per 50 steps: 0.768462598323822
# Training loss per 50 steps: 0.6144865155220032
# Training loss per 50 steps: 0.5809707601766775
# Training loss per 50 steps: 0.552580099959938
# Training loss per 50 steps: 0.5719821051560083
# Training loss per 50 steps: 0.562136928302299
# Training loss per 50 steps: 0.5564310089731435
# Epoch: 8
# The total loss: 0.5514633886685426
# Pearson r: 0.531
# Saved the model in epoch 8
# Training loss per 50 steps: 0.7838199138641357
# Training loss per 50 steps: 0.42045923220176323
# Training loss per 50 steps: 0.42595203567554457
# Training loss per 50 steps: 0.4407341443248932
# Training loss per 50 steps: 0.4492041697697853
# Training loss per 50 steps: 0.45453683755905977
# Training loss per 50 steps: 0.44949623801284455
# Epoch: 9
# The total loss: 0.4470946940734531
# Pearson r: 0.504
# Training loss per 50 steps: 0.23788800835609436
# Training loss per 50 steps: 0.31173079051807817
# Training loss per 50 steps: 0.34759229347847476
# Training loss per 50 steps: 0.34525434579083464
# Training loss per 50 steps: 0.3383069161084754
# Training loss per 50 steps: 0.3432178529372728
# Training loss per 50 steps: 0.3408829085900142
# Epoch: 10
# The total loss: 0.34544738499504146
# Pearson r: 0.522
# Training loss per 50 steps: 0.4273514449596405
# Training loss per 50 steps: 0.3107522414887653
# Training loss per 50 steps: 0.28935429767364323
# Training loss per 50 steps: 0.2930150560245214
# Training loss per 50 steps: 0.2873251189232169
# Training loss per 50 steps: 0.290361992614084
# Training loss per 50 steps: 0.29699219197678406
# Epoch: 11
# The total loss: 0.2968250044931968
# Pearson r: 0.514
# Training loss per 50 steps: 0.19080834090709686
# Training loss per 50 steps: 0.20572293969784297
# Training loss per 50 steps: 0.2321509864033744
# Training loss per 50 steps: 0.23578516328522306
# Training loss per 50 steps: 0.2413780520952756
# Training loss per 50 steps: 0.23974283981281685
# Training loss per 50 steps: 0.2432865337638859
# Epoch: 12
# The total loss: 0.2458643704483455
# Pearson r: 0.517
# Training loss per 50 steps: 0.2845092713832855
# Training loss per 50 steps: 0.22196787639575846
# Training loss per 50 steps: 0.20930644021470948
# Training loss per 50 steps: 0.20698185094835742
# Training loss per 50 steps: 0.2078074509676416
# Training loss per 50 steps: 0.20716824815923948
# Training loss per 50 steps: 0.2073642103081922
# Epoch: 13
# The total loss: 0.21027272314284787
# Pearson r: 0.492
# Training loss per 50 steps: 0.13613808155059814
# Training loss per 50 steps: 0.21503619878899818
# Training loss per 50 steps: 0.20133964462888124
# Training loss per 50 steps: 0.19821235887854305
# Training loss per 50 steps: 0.19527302774141975
# Training loss per 50 steps: 0.1958634300283583
# Training loss per 50 steps: 0.1951638498464197
# Epoch: 14
# The total loss: 0.1963785613633015
# Pearson r: 0.546
# Saved the model in epoch 14
# Training loss per 50 steps: 0.15473869442939758
# Training loss per 50 steps: 0.19189867121624013
# Training loss per 50 steps: 0.19434714670486675
# Training loss per 50 steps: 0.1845117372380483
# Training loss per 50 steps: 0.18866733837390864
# Training loss per 50 steps: 0.19108546956023015
# Training loss per 50 steps: 0.19339256717876047
# Epoch: 15
# The total loss: 0.19364723719261362
# Pearson r: 0.525
# Training loss per 50 steps: 0.20202361047267914
# Training loss per 50 steps: 0.16740412597416662
# Training loss per 50 steps: 0.15908101911075634
# Training loss per 50 steps: 0.1646545667645355
# Training loss per 50 steps: 0.16946185624866344
# Training loss per 50 steps: 0.1699776201698172
# Training loss per 50 steps: 0.16783878468967156
# Epoch: 16
# The total loss: 0.168085637468506
# Pearson r: 0.509
# Training loss per 50 steps: 0.11987032741308212
# Training loss per 50 steps: 0.1687185782573971
# Training loss per 50 steps: 0.158554594373644
# Training loss per 50 steps: 0.1739687705474184
# Training loss per 50 steps: 0.16666158084845661
# Training loss per 50 steps: 0.15934392080764728
# Training loss per 50 steps: 0.158204464362532
# Epoch: 17
# The total loss: 0.15552462091330777
# Pearson r: 0.537
# Training loss per 50 steps: 0.21835875511169434
# Training loss per 50 steps: 0.16956744511045663
# Training loss per 50 steps: 0.1605445066891094
# Training loss per 50 steps: 0.15749295865068372
# Training loss per 50 steps: 0.15126640887106235
# Training loss per 50 steps: 0.15964990852779126
# Training loss per 50 steps: 0.153666593648023
# Epoch: 18
# The total loss: 0.15519872356883505
# Pearson r: 0.538
# Training loss per 50 steps: 0.13802561163902283
# Training loss per 50 steps: 0.11943566477766224
# Training loss per 50 steps: 0.12853485530260766
# Training loss per 50 steps: 0.13473277936214642
# Training loss per 50 steps: 0.13562048292389853
# Training loss per 50 steps: 0.14051990097470254
# Training loss per 50 steps: 0.1444501801644548
# Epoch: 19
# The total loss: 0.14440966659423077
# Pearson r: 0.528
# Training loss per 50 steps: 0.27247244119644165
# Training loss per 50 steps: 0.12658134398653226
# Training loss per 50 steps: 0.13308120470973525
# Training loss per 50 steps: 0.14315144078719694
# Training loss per 50 steps: 0.1450207098503018
# Training loss per 50 steps: 0.14768105957553207
# Training loss per 50 steps: 0.1504899788542691
# Epoch: 20
# The total loss: 0.14800474488204626
# Pearson r: 0.521

# %% [markdown]
# # Test

# %%
test_loader = data_module.dataloader(file=test_file, send_label=False, shuffle=False)
pred = trainer.evaluate(dataloader=test_loader, load_model=True)
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
pred_df = pd.DataFrame({'emp': pred, 'dis': pred})

# %%
pred_df
# Out:
#          emp       dis
# 0   4.743536  4.743536
# 1   5.375017  5.375017
# 2   5.558261  5.558261
# 3   4.441684  4.441684
# 4   4.513950  4.513950
# ..       ...       ...
# 95  5.794048  5.794048
# 96  5.106700  5.106700
# 97  3.298420  3.298420
# 98  4.998303  4.998303
# 99  5.430133  5.430133
#
# [100 rows x 2 columns]

# %%
pred_df.to_csv('./tmp/predictions_EMP.tsv', sep='\t', index=None, header=None)

# %% [markdown]
# # Extra

# %% [markdown]
# ## Combined guide and final

# %%
class GuidedRegression(nn.Module):
    def __init__(self, checkpoint):
        super(GuidedRegression, self).__init__()
        self.transformer = AutoModel.from_pretrained(checkpoint)
        self.dropout = nn.Dropout(0.2)
        
        self.pre_classifier = nn.Linear(768, 768)
        self.pre_classifier_guide = nn.Linear(769, 768)
        
        self.classifier = nn.Linear(768, 512)
        self.pre_final = nn.Linear(512, 256)
        self.final = nn.Linear(256, 1)

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        # token_type_ids=None,
        guide=None
    ):

        output = self.transformer(
            input_ids=input_ids,
            attention_mask=attention_mask,
            # token_type_ids=token_type_ids
        )
        
        output = output[0]
        output = output[:, 0]

        if guide is None:
            output = self.pre_classifier(output)
        else:
            output = torch.cat([output, guide], 1)
            output = self.pre_classifier_guide(output)
        
        output = nn.ReLU()(output)
        output = self.dropout(output)
        output = self.classifier(output)
        output = nn.ReLU()(output)
        output = self.pre_final(output)
        output = nn.ReLU()(output)
        output = self.final(output)
        return output

# %%
class Trainer:
    def __init__(self, task_guide, task_predictor, model, lr):
        self.device = get_device(0)
        
        self.task_guide = task_guide
        self.task_predictor = task_predictor
        self.model = model.to(self.device)
        
        self.lr = lr
        self.loss_fn = nn.MSELoss()
        
        self.optimizer = torch.optim.Adam(params=self.model.parameters(), lr = self.lr)
        
        self.best_pearson_r = -1.0 # initiliasation

    def _training_step(self, epoch, train_loader):
        tr_loss = 0.0
        
        self.model.train()
    
        for i, data in enumerate(train_loader, 0):
            input_ids = data['input_ids'].to(self.device, dtype=torch.long)
            attention_mask = data['attention_mask'].to(self.device, dtype=torch.long)
            # token_type_ids = data['token_type_ids'].to(self.device, dtype=torch.long)
            guide = data[self.task_guide].to(self.device, dtype=torch.float).view(-1, 1)
            targets = data[self.task_predictor].to(self.device, dtype=torch.float).view(-1, 1)
            
            outputs = self.model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                # token_type_ids=token_type_ids,
                guide=None
            )          
            loss = self.loss_fn(outputs, guide)
            self.optimizer.zero_grad()
            loss.backward(retain_graph=True)
            self.optimizer.step()

            final_outputs = self.model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                # token_type_ids=token_type_ids,
                guide=outputs
            )
            
            final_loss = self.loss_fn(final_outputs, targets)
            self.optimizer.zero_grad()
            final_loss.backward()
            self.optimizer.step()
            
            tr_loss += final_loss.item()
    
            if i % 50 == 0:
                loss_step = tr_loss / (i+1)
                print(f'Training loss per 50 steps: {loss_step}')
    
        epoch_loss = tr_loss / (i+1)
        print(f'Epoch: {epoch+1}')
        print(f'The total loss: {epoch_loss}')

    def fit(self, n_epochs, train_loader, dev_loader, output_label, save_model=False):
        set_all_seeds(0)
        for epoch in range(n_epochs):
            self._training_step(epoch, train_loader)

            preds = self.evaluate(dataloader=dev_loader, load_model=False)
            if self.task_predictor == 'empathy':
                true = output_label.iloc[:, 0].tolist()
            if self.task_predictor == 'distress':
                true = output_label.iloc[:, 1].tolist()
            pearson_r = pearsonr(true, preds)
            print(f'Pearson r: {pearson_r}')
            
            if save_model and (pearson_r > self.best_pearson_r):
                self.best_pearson_r = pearson_r   
                torch.save(self.model.state_dict(), 'roberta-empathy.pth')
                print("Saved the model in epoch " + str(epoch+1))

    def evaluate(self, dataloader, load_model=False):
        if load_model:
            self.model.load_state_dict(torch.load('roberta-empathy.pth'))
    
        pred = torch.empty((len(dataloader.dataset), 1), device=self.device) # len(self.dev_loader.dataset) --> # of samples
        
        self.model.eval()
    
        with torch.no_grad():
            idx = 0
            for data in dataloader:
                input_ids = data['input_ids'].to(self.device, dtype=torch.long)
                attention_mask = data['attention_mask'].to(self.device, dtype=torch.long)
                # token_type_ids = data['token_type_ids'].to(self.device, dtype=torch.long)
                
                outputs = self.model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    # token_type_ids=token_type_ids,
                    guide=None
                )
    
                final_outputs = self.model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    # token_type_ids=token_type_ids,
                    guide=outputs
                )

                batch_size = final_outputs.shape[0]
                pred[idx:idx+batch_size, :] = final_outputs
                idx += batch_size
            
        return [float(k) for k in pred]

# %%
model = GuidedRegression(checkpoint=checkpoint)

trainer = Trainer(
    task_guide=task_list[1],
    task_predictor=task_list[0],
    model=model,
    lr=lr
)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.fit(n_epochs=20, train_loader=train_loader, dev_loader=dev_loader,
            output_label=dev_label, save_model=False)
# Out:
# Training loss per 50 steps: 10.352550506591797
# Training loss per 50 steps: 13.305788320653578
# Training loss per 50 steps: 9.461502163717062
# Training loss per 50 steps: 7.592380867888596
# Training loss per 50 steps: 6.637593874883889
# Training loss per 50 steps: 6.020316544282009
# Training loss per 50 steps: 5.642060121824575
# Epoch: 1
# The total loss: 5.467915393728198
# Pearson r: 0.125
# Training loss per 50 steps: 4.183372974395752
# Training loss per 50 steps: 3.317987002578436
# Training loss per 50 steps: 3.424180183965381
# Training loss per 50 steps: 3.474616882619479
# Training loss per 50 steps: 3.39283124249966
# Training loss per 50 steps: 3.3362700516484174
# Training loss per 50 steps: 3.303164756377274
# Epoch: 2
# The total loss: 3.2939254133990317
# Pearson r: 0.317
# Training loss per 50 steps: 2.191816806793213
# Training loss per 50 steps: 2.84420525560192
# Training loss per 50 steps: 2.738071873636529
# Training loss per 50 steps: 2.7836127170663794
# Training loss per 50 steps: 2.7267616471247886
# Training loss per 50 steps: 2.6978501802777863
# Training loss per 50 steps: 2.6649850909397057
# Epoch: 3
# The total loss: 2.646875496660218
# Pearson r: 0.558
# Training loss per 50 steps: 1.1527996063232422
# Training loss per 50 steps: 2.0195956633371464
# Training loss per 50 steps: 2.032822457575562
# Training loss per 50 steps: 1.9694491488649355
# Training loss per 50 steps: 2.0090627579843225
# Training loss per 50 steps: 2.0275389249343796
# Training loss per 50 steps: 2.0249343358995113
# Epoch: 4
# The total loss: 2.0455812823591812
# Pearson r: 0.613
# Training loss per 50 steps: 1.6494178771972656
# Training loss per 50 steps: 1.5589668400147383
# Training loss per 50 steps: 1.5242337823504268
# Training loss per 50 steps: 1.5010480511662185
# Training loss per 50 steps: 1.5152141232395646
# Training loss per 50 steps: 1.5535032784796332
# Training loss per 50 steps: 1.5791964160148488
# Epoch: 5
# The total loss: 1.5943899454040962
# Pearson r: 0.518
# Training loss per 50 steps: 1.5678131580352783
# Training loss per 50 steps: 1.2838687587018107
# Training loss per 50 steps: 1.2757761658418296
# Training loss per 50 steps: 1.232062265869008
# Training loss per 50 steps: 1.2030035352973796
# Training loss per 50 steps: 1.165137551992063
# Training loss per 50 steps: 1.1512464189846254
# Epoch: 6
# The total loss: 1.1274459738623013
# Pearson r: 0.516
# Training loss per 50 steps: 2.7330262660980225
# Training loss per 50 steps: 0.8315758152919657
# Training loss per 50 steps: 0.8455162310954367
# Training loss per 50 steps: 0.8294735996928436
# Training loss per 50 steps: 0.7951358553411355
# Training loss per 50 steps: 0.779222420042017
# Training loss per 50 steps: 0.79708260725998
# Epoch: 7
# The total loss: 0.8081061141734773
# Pearson r: 0.467
# Training loss per 50 steps: 0.22875069081783295
# Training loss per 50 steps: 0.5946363134711397
# Training loss per 50 steps: 0.5983373664024443
# Training loss per 50 steps: 0.6077892319206765
# Training loss per 50 steps: 0.6062532274691916
# Training loss per 50 steps: 0.5971588705373237
# Training loss per 50 steps: 0.5896987452038697
# Epoch: 8
# The total loss: 0.5935076557212706
# Pearson r: 0.487
# Training loss per 50 steps: 0.34275001287460327
# Training loss per 50 steps: 0.5143847182100895
# Training loss per 50 steps: 0.4583662676781711
# Training loss per 50 steps: 0.44816681880824616
# Training loss per 50 steps: 0.44258636002665136
# Training loss per 50 steps: 0.4592889322940097
# Training loss per 50 steps: 0.4487553233423106
# Epoch: 9
# The total loss: 0.4548395099287683
# Pearson r: 0.461
# Training loss per 50 steps: 0.5420547127723694
# Training loss per 50 steps: 0.4507760905167636
# Training loss per 50 steps: 0.42642467948469787
# Training loss per 50 steps: 0.4056114180395935
# Training loss per 50 steps: 0.39256808984635483
# Training loss per 50 steps: 0.39236450459496436
# Training loss per 50 steps: 0.38291935788535597
# Epoch: 10
# The total loss: 0.37701101099902934
# Pearson r: 0.511
# Training loss per 50 steps: 0.7367095947265625
# Training loss per 50 steps: 0.3308548170561884
# Training loss per 50 steps: 0.3203585075933744
# Training loss per 50 steps: 0.3168820214044574
# Training loss per 50 steps: 0.3279483845429634
# Training loss per 50 steps: 0.3252000054604266
# Training loss per 50 steps: 0.31836329536679575
# Epoch: 11
# The total loss: 0.31554420333017
# Pearson r: 0.515
# Training loss per 50 steps: 0.44038593769073486
# Training loss per 50 steps: 0.31392905371738417
# Training loss per 50 steps: 0.2944877422829666
# Training loss per 50 steps: 0.29082392817301467
# Training loss per 50 steps: 0.2855561001976924
# Training loss per 50 steps: 0.289123683514823
# Training loss per 50 steps: 0.298688240225529
# Epoch: 12
# The total loss: 0.29673214362877787
# Pearson r: 0.52
# Training loss per 50 steps: 0.10290137678384781
# Training loss per 50 steps: 0.23127070573322914
# Training loss per 50 steps: 0.23227421209068583
# Training loss per 50 steps: 0.2383711842314297
# Training loss per 50 steps: 0.232649304917944
# Training loss per 50 steps: 0.23886443417801326
# Training loss per 50 steps: 0.23708517032604282
# Epoch: 13
# The total loss: 0.24382135427669818
# Pearson r: 0.514
# Training loss per 50 steps: 0.05285657197237015
# Training loss per 50 steps: 0.19673625379800797
# Training loss per 50 steps: 0.2234739730558773
# Training loss per 50 steps: 0.22421679386733384
# Training loss per 50 steps: 0.2241551113402962
# Training loss per 50 steps: 0.2174331776471252
# Training loss per 50 steps: 0.22077054428277024
# Epoch: 14
# The total loss: 0.22009045359198795
# Pearson r: 0.524
# Training loss per 50 steps: 0.18017451465129852
# Training loss per 50 steps: 0.23922477764826194
# Training loss per 50 steps: 0.2099352292163242
# Training loss per 50 steps: 0.2015486860536779
# Training loss per 50 steps: 0.19754800950153847
# Training loss per 50 steps: 0.1978786634541009
# Training loss per 50 steps: 0.1995739252105405
# Epoch: 15
# The total loss: 0.19762687484987757
# Pearson r: 0.513
# Training loss per 50 steps: 0.507510244846344
# Training loss per 50 steps: 0.197858662801046
# Training loss per 50 steps: 0.1994182638233841
# Training loss per 50 steps: 0.2015536946571426
# Training loss per 50 steps: 0.1973415883953002
# Training loss per 50 steps: 0.19989624407246293
# Training loss per 50 steps: 0.19989374406214963
# Epoch: 16
# The total loss: 0.20177513154392893
# Pearson r: 0.526
# Training loss per 50 steps: 0.07991069555282593
# Training loss per 50 steps: 0.19188202647309677
# Training loss per 50 steps: 0.20262693292876283
# Training loss per 50 steps: 0.18716635101086257
# Training loss per 50 steps: 0.19085557345504783
# Training loss per 50 steps: 0.1929532241714428
# Training loss per 50 steps: 0.1931013666538899
# Epoch: 17
# The total loss: 0.19615736701949077
# Pearson r: 0.524
# Training loss per 50 steps: 0.2532930374145508
# Training loss per 50 steps: 0.18849454447627068
# Training loss per 50 steps: 0.17114808753427893
# Training loss per 50 steps: 0.1739826062509161
# Training loss per 50 steps: 0.17242247229488336
# Training loss per 50 steps: 0.1714133165249846
# Training loss per 50 steps: 0.1729628971601493
# Epoch: 18
# The total loss: 0.17125114662234078
# Pearson r: 0.515
# Training loss per 50 steps: 0.10899434238672256
# Training loss per 50 steps: 0.14003418758511543
# Training loss per 50 steps: 0.14340206372118233
# Training loss per 50 steps: 0.15085236141026415
# Training loss per 50 steps: 0.15023270393003577
# Training loss per 50 steps: 0.14907885161024403
# Training loss per 50 steps: 0.15060395729477422
# Epoch: 19
# The total loss: 0.15345529571288463
# Pearson r: 0.525
# Training loss per 50 steps: 0.02085277810692787
# Training loss per 50 steps: 0.15116656688498517
# Training loss per 50 steps: 0.15541652373342527
# Training loss per 50 steps: 0.15845787232211292
# Training loss per 50 steps: 0.16049674170935035
# Training loss per 50 steps: 0.16055091275310374
# Training loss per 50 steps: 0.16369310836385056
# Epoch: 20
# The total loss: 0.16933809769988964
# Pearson r: 0.516
